# %%
from pipeline import intracellular

# %%
intracellular.MembranePotential.populate()
# Out:
# Found datafile: cell_20_1.nwb
# Insert intracellular data for: subject: anm300476 - date: 2017-05-20 18:28:59 - cell: cell_20_1
# Write PatchClampSeries: anm300476_170520_182859_cell_20_1_membrane_potential.nwb
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-4666b7f0abe2> in <module>
# ----> 1 intracellular.MembranePotential.populate()
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     158                     self.__class__._allow_insert = True
#     159                     try:
# --> 160                         make(dict(key))
#     161                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     162                         try:
#
# ~/Dropbox/Vathes/nwb/nwb_hackathons/HCK07_2020_Seattle/projects/breakout_datajoint/pipeline/intracellular.py in make(self, key)
#      97
#      98         # -- MembranePotential
# ---> 99         self.insert1(dict(key, nwb_patch_clamp=patch_clamp))
#     100         nwb.close()
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in insert1(self, row, **kwargs)
#     173         For kwargs, see insert()
#     174         """
# --> 175         self.insert((row,), **kwargs)
#     176
#     177     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, allow_direct_insert=None):
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, allow_direct_insert)
#     329             return row_to_insert
#     330
# --> 331         rows = list(make_row_to_insert(row) for row in rows)
#     332         if rows:
#     333             try:
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in <genexpr>(.0)
#     329             return row_to_insert
#     330
# --> 331         rows = list(make_row_to_insert(row) for row in rows)
#     332         if rows:
#     333             try:
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in make_row_to_insert(row)
#     299             elif isinstance(row, collections.abc.Mapping):  # dict-based
#     300                 check_fields(row)
# --> 301                 attributes = [make_placeholder(name, row[name]) for name in heading if name in row]
#     302             else:  # positional
#     303                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in <listcomp>(.0)
#     299             elif isinstance(row, collections.abc.Mapping):  # dict-based
#     300                 check_fields(row)
# --> 301                 attributes = [make_placeholder(name, row[name]) for name in heading if name in row]
#     302             else:  # positional
#     303                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/datajoint/table.py in make_placeholder(name, value)
#     249                 attr = heading[name]
#     250                 if attr.adapter:
# --> 251                     value = attr.adapter.put(value)
#     252                 if value is None or (attr.numeric and (value == '' or np.isnan(np.float(value)))):
#     253                     # set default value
#
# ~/Dropbox/Vathes/nwb/nwb_hackathons/HCK07_2020_Seattle/projects/breakout_datajoint/pipeline/nwb_adapter.py in put(self, patch_clamp)
#      79
#      80         print(f'Write PatchClampSeries: {save_file_name}')
# ---> 81         _write_nwb(save_fp, nwb, manager=nwb.io.manager)
#      82         return save_fp.as_posix()
#      83
#
# ~/Dropbox/Vathes/nwb/nwb_hackathons/HCK07_2020_Seattle/projects/breakout_datajoint/pipeline/nwb_adapter.py in _write_nwb(save_fp, nwb2write, manager)
#     100         if save_fp.exists():
#     101             save_fp.unlink()
# --> 102         raise e
#     103
#     104
#
# ~/Dropbox/Vathes/nwb/nwb_hackathons/HCK07_2020_Seattle/projects/breakout_datajoint/pipeline/nwb_adapter.py in _write_nwb(save_fp, nwb2write, manager)
#      95 def _write_nwb(save_fp, nwb2write, manager=None):
#      96     try:
# ---> 97         with NWBHDF5IO(save_fp.as_posix(), mode='w', manager=manager) as io:
#      98             io.write(nwb2write)
#      99     except Exception as e:
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/utils.py in func_call(*args, **kwargs)
#     451
#     452             if is_method:
# --> 453                 return func(args[0], **parsed['args'])
#     454             else:
#     455                 return func(**parsed['args'])
#
# ~/anaconda3/lib/python3.7/site-packages/pynwb/__init__.py in __init__(self, **kwargs)
#     244             elif manager is None:
#     245                 manager = get_manager()
# --> 246         super(NWBHDF5IO, self).__init__(path, manager=manager, mode=mode, file=file_obj, comm=comm)
#     247
#     248
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/utils.py in func_call(*args, **kwargs)
#     451
#     452             if is_method:
# --> 453                 return func(args[0], **parsed['args'])
#     454             else:
#     455                 return func(**parsed['args'])
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/backends/hdf5/h5tools.py in __init__(self, **kwargs)
#      66         self.__path = path
#      67         self.__file = file_obj
# ---> 68         super().__init__(manager, source=path)
#      69         self.__built = dict()       # keep track of each builder for each dataset/group/link for each file
#      70         self.__read = dict()        # keep track of which files have been read. Key is the filename value is the builder
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/utils.py in func_call(*args, **kwargs)
#     451
#     452             if is_method:
# --> 453                 return func(args[0], **parsed['args'])
#     454             else:
#     455                 return func(**parsed['args'])
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/backends/io.py in __init__(self, **kwargs)
#      15         self.__built = dict()
#      16         self.__source = getargs('source', kwargs)
# ---> 17         self.open()
#      18
#      19     @property
#
# ~/anaconda3/lib/python3.7/site-packages/hdmf/backends/hdf5/h5tools.py in open(self)
#     520             else:
#     521                 kwargs = {}
# --> 522             self.__file = File(self.__path, open_flag, **kwargs)
#     523
#     524     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# ~/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     174         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     175     elif mode == 'w':
# --> 176         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     177     elif mode == 'a':
#     178         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to truncate a file which is already open)

# %%
intracellular.MembranePotential()
# Out:
# About to delete:
# `demo_intracellular`.`_membrane_potential`: 3 items
# Proceed? [yes, No]: yes
# Committed.

# %%
nwb_patch_clamp = (intracellular.MembranePotential & 'cell_id="cell_20_1"').fetch1('nwb_patch_clamp')
